# %%
import sys
sys.path.append('/home/zwt/Bigscity-LibCity')
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from logging import getLogger
from libcity.model.abstract_traffic_state_model import AbstractTrafficStateModel
from libcity.model import loss
from scipy.sparse.linalg import eigs

# %%
from Embedding import GNN_Based_Layers as GNN
from ST_backbone import CNN_Based_Models as TCNN
from ST_backbone import STAttention_Based_Models as Attn
from Output import LinearTransform as LT


class ASTGCNBlock(nn.Module):
    def __init__(self, device, in_channels, k, nb_chev_filter, nb_time_filter,
                 time_strides, cheb_polynomials, num_of_nodes, num_of_timesteps):
        super(ASTGCNBlock, self).__init__()
        self.TAt = Attn.TemporalAttention(device, in_channels, num_of_nodes, num_of_timesteps)
        self.SAt = Attn.SpatialAttention(device, in_channels, num_of_nodes, num_of_timesteps)
        self.cheb_conv_SAt = GNN.ChebConvWithSAt(k, cheb_polynomials, in_channels, nb_chev_filter)
        # 时间卷积: 输入时间长度 = num_of_timesteps = time_strides * output_window
        # 输入必须是输出output_window的固定倍数！
        # ker=3, pad=2, stride=time_strides
        # 输出时间长度 = (time_strides * output_window + 2 * pad - ker) / time_strides + 1 = output_window
        self.time_conv = nn.Conv2d(nb_chev_filter, nb_time_filter, kernel_size=(1, 3),
                                   stride=(1, time_strides), padding=(0, 1))
        # 时间维度上卷积: 输入时间长度 = num_of_timesteps = time_strides * output_window
        # ker=1, stride=time_strides
        # 输出时间长度 = (time_strides * output_window - ker) / time_strides + 1 = output_window
        self.residual_conv = nn.Conv2d(in_channels, nb_time_filter, kernel_size=(1, 1), stride=(1, time_strides))
        self.ln = nn.LayerNorm(nb_time_filter)  # 需要将channel放到最后一个维度上

    def forward(self, x):
        """
        Args:
            x: (batch_size, N, F_in, T)

        Returns:
            torch.tensor: (batch_size, N, nb_time_filter, output_window)
        """
        batch_size, num_of_vertices, num_of_features, num_of_timesteps = x.shape

        # TAt
        temporal_at = self.TAt(x)  # (B, T, T)

        x_tat = torch.matmul(x.reshape(batch_size, -1, num_of_timesteps), temporal_at)\
            .reshape(batch_size, num_of_vertices, num_of_features, num_of_timesteps)
        # 结合时间注意力：(B, N*F_in, T) * (B, T, T) -> (B, N*F_in, T) -> (B, N, F_in, T)

        # SAt
        spatial_at = self.SAt(x_tat)  # (B, N, N)

        # 结合空间注意力的图卷积 cheb gcn
        spatial_gcn = self.cheb_conv_SAt(x, spatial_at)  # (B, N, F_out, T), F_out = nb_chev_filter

        # convolution along the time axis
        time_conv_output = self.time_conv(spatial_gcn.permute(0, 2, 1, 3))
        # (B, N, F_out, T) -> (B, F_out, N, T) 用(1,3)的卷积核去做->(B, F_out', N, T') F_out'=nb_time_filter

        # residual shortcut
        x_residual = self.residual_conv(x.permute(0, 2, 1, 3))
        # (B, N, F_in, T) -> (B, F_in, N, T) 用(1,1)的卷积核去做->(B, F_out', N, T') F_out'=nb_time_filter

        x_residual = self.ln(F.relu(x_residual + time_conv_output).permute(0, 3, 2, 1)).permute(0, 2, 3, 1)
        # (B, F_out', N, T') -> (B, T', N, F_out') -ln -> (B, T', N, F_out') -> (B, N, F_out', T')

        return x_residual

class ASTGCNSubmodule(nn.Module):
    def __init__(self, device, nb_block, in_channels, k, nb_chev_filter, nb_time_filter,
                 time_strides, cheb_polynomials, output_window, output_dim, num_of_vertices):
        super(ASTGCNSubmodule, self).__init__()

        self.BlockList = nn.ModuleList([ASTGCNBlock(device, in_channels, k, nb_chev_filter,
                                                    nb_time_filter, time_strides, cheb_polynomials,
                                                    num_of_vertices, time_strides * output_window)])

        self.BlockList.extend([ASTGCNBlock(device, nb_time_filter, k, nb_chev_filter,
                                           nb_time_filter, 1, cheb_polynomials,
                                           num_of_vertices, output_window)
                               for _ in range(nb_block-1)])

        self.final_conv = nn.Conv2d(output_window, output_window,
                                    kernel_size=(1, nb_time_filter - output_dim + 1))

        self.fusionlayer = LT.FusionLayer(output_window, num_of_vertices, output_dim, device)

    def forward(self, x):
        """
        Args:
            x: (B, T_in, N_nodes, F_in)

        Returns:
            torch.tensor: (B, T_out, N_nodes, out_dim)
        """
        x = x.permute(0, 2, 3, 1)  # (B, N, F_in(feature_dim), T_in)
        for block in self.BlockList:
            x = block(x)  # 每个时空块的输出维度是nb_time_filter
        # (B, N, F_out(nb_time_filter), T_out(output_window))
        # 将nb_time_filter变成output_dim
        output = self.final_conv(x.permute(0, 3, 1, 2))
        # (B, N, F_out, T_out) --> (B, T_out, N, F_out) --> conv<1,F_out-out_dim+1> --> (B, T_out, N, out_dim)
        output = self.fusionlayer(output)
        return output

# %%
class ASTGCN(AbstractTrafficStateModel):
    def __init__(self, config, data_feature):
        super().__init__(config, data_feature)

        self.num_nodes = self.data_feature.get('num_nodes', 1)
        self.feature_dim = self.data_feature.get('feature_dim', 1)
        self.len_period = self.data_feature.get('len_period', 0)
        self.len_trend = self.data_feature.get('len_trend', 0)
        self.len_closeness = self.data_feature.get('len_closeness', 0)
        if self.len_period == 0 and self.len_trend == 0 and self.len_closeness == 0:
            raise ValueError('Num of days/weeks/hours are all zero! Set at least one of them not zero!')
        self.output_dim = self.data_feature.get('output_dim', 1)

        self.output_window = config.get('output_window', 1)
        self.device = config.get('device', torch.device('cpu'))
        self.nb_block = config.get('nb_block', 2)
        self.K = config.get('K', 3)
        self.nb_chev_filter = config.get('nb_chev_filter', 64)
        self.nb_time_filter = config.get('nb_time_filter', 64)

        adj_mx = self.data_feature.get('adj_mx')
        l_tilde = GNN.scaled_laplacian(adj_mx)
        self.cheb_polynomials = [torch.from_numpy(i).type(torch.FloatTensor).to(self.device)
                                 for i in GNN.cheb_polynomial(l_tilde, self.K)]
        self._logger = getLogger()
        self._scaler = self.data_feature.get('scaler')

        if self.len_closeness > 0:
            self.hours_ASTGCN_submodule = \
                ASTGCNSubmodule(self.device, self.nb_block, self.feature_dim,
                                self.K, self.nb_chev_filter, self.nb_time_filter,
                                self.len_closeness // self.output_window, self.cheb_polynomials,
                                self.output_window, self.output_dim, self.num_nodes)
        if self.len_period > 0:
            self.days_ASTGCN_submodule = \
                ASTGCNSubmodule(self.device, self.nb_block, self.feature_dim,
                                self.K, self.nb_chev_filter, self.nb_time_filter,
                                self.len_period // self.output_window, self.cheb_polynomials,
                                self.output_window, self.output_dim, self.num_nodes)
        if self.len_trend > 0:
            self.weeks_ASTGCN_submodule = \
                ASTGCNSubmodule(self.device, self.nb_block, self.feature_dim,
                                self.K, self.nb_chev_filter, self.nb_time_filter,
                                self.len_trend // self.output_window, self.cheb_polynomials,
                                self.output_window, self.output_dim, self.num_nodes)
        self._init_parameters()

    def _init_parameters(self):
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
            else:
                nn.init.uniform_(p)

    def forward(self, batch):
        x = batch['X']  # (B, Tw+Td+Th, N_nodes, F_in)
        # 时间维度(第1维)上的顺序是CPT，即
        # [0, len_closeness) -- input1
        # [len_closeness, len_closeness+len_period) -- input2
        # [len_closeness+len_period, len_closeness+len_period+len_trend) -- input3
        output = 0
        if self.len_closeness > 0:
            begin_index = 0
            end_index = begin_index + self.len_closeness
            output_hours = self.hours_ASTGCN_submodule(x[:, begin_index:end_index, :, :])
            output += output_hours
        if self.len_period > 0:
            begin_index = self.len_closeness
            end_index = begin_index + self.len_period
            output_days = self.days_ASTGCN_submodule(x[:, begin_index:end_index, :, :])
            output += output_days
        if self.len_trend > 0:
            begin_index = self.len_closeness + self.len_period
            end_index = begin_index + self.len_trend
            output_weeks = self.weeks_ASTGCN_submodule(x[:, begin_index:end_index, :, :])
            output += output_weeks
        return output  # (B, Tp, N_nodes, F_out)

    def calculate_loss(self, batch):
        y_true = batch['y']
        y_predicted = self.predict(batch)
        y_true = self._scaler.inverse_transform(y_true[..., :self.output_dim])
        y_predicted = self._scaler.inverse_transform(y_predicted[..., :self.output_dim])
        return loss.masked_mse_torch(y_predicted, y_true)

    def predict(self, batch):
        return self.forward(batch)

# %%
from libcity.data import get_dataset
from libcity.utils import get_executor
from libcity.utils import get_model
from libcity.utils import get_logger

config = {'task': 'traffic_state_pred', 'model': 'ASTGCN', 'dataset': 'PEMSD4', 'saved_model': True, 'train': True, 'dataset_class': 'ASTGCNDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'nb_block': 2, 'K': 3, 'nb_chev_filter': 64, 'nb_time_filter': 64, 'scaler': 'standard', 'load_external': False, 'normal_external': False, 'ext_scaler': 'none', 'add_time_in_day': False, 'add_day_in_week': False, 'train_rate': 0.6, 'eval_rate': 0.2, 'max_epoch': 100, 'learner': 'adam', 'learning_rate': 0.0001, 'lr_decay': False, 'clip_grad_norm': False, 'use_early_stop': False, 'batch_size': 64, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'input_window': 12, 'output_window': 12, 'len_closeness': 2, 'len_period': 1, 'len_trend': 2, 'interval_period': 1, 'interval_trend': 7, 'gpu': True, 'gpu_id': 0, 'train_loss': 'none', 'epoch': 0, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.1, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'max_grad_norm': 1.0, 'patience': 50, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'mode': 'single', 'save_modes': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'cost': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'traffic_flow': 'num', 'traffic_occupancy': 'num', 'traffic_speed': 'num'}}, 'data_col': ['traffic_flow', 'traffic_occupancy', 'traffic_speed'], 'weight_col': 'cost', 'data_files': ['PEMSD4'], 'geo_file': 'PEMSD4', 'rel_file': 'PEMSD4', 'output_dim': 3, 'time_intervals': 300, 'init_weight_inf_or_zero': 'zero', 'set_weight_link_or_dist': 'link', 'calculate_weight_adj': False, 'weight_adj_epsilon': 0.1}
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import torch
config['device'] = torch.device("cuda" if torch.cuda.is_available() and config['gpu'] else "cpu")

logger = get_logger(config)
# 加载数据集
dataset = get_dataset(config)
# 转换数据，并划分数据集
train_data, valid_data, test_data = dataset.get_data()
print(len(train_data), len(train_data.dataset), train_data.dataset[0][0].shape, train_data.dataset[0][1].shape, train_data.batch_size)
print(len(valid_data), len(valid_data.dataset), valid_data.dataset[0][0].shape, valid_data.dataset[0][1].shape, valid_data.batch_size)
print(len(test_data), len(test_data.dataset), test_data.dataset[0][0].shape, test_data.dataset[0][1].shape, test_data.batch_size)

data_feature = dataset.get_data_feature()
print(data_feature['adj_mx'].shape)
print(data_feature['adj_mx'].sum())

model = get_model(config, data_feature)

# 加载执行器
model_cache_file = './libcity/cache/model_cache/' + config['model'] + '_' + config['dataset'] + '.m'
executor = get_executor(config, model)

# 训练
executor.train(train_data, valid_data)
executor.save_model(model_cache_file)
executor.load_model(model_cache_file)
# 评估，评估结果将会放在 cache/evaluate_cache 下
executor.evaluate(test_data)
# Out:
# 2021-12-03 21:23:48,078 - INFO - Log directory: ./libcity/log
# 2021-12-03 21:23:48,740 - INFO - Loaded file PEMSD4.geo, num_nodes=307
# 2021-12-03 21:23:48,744 - INFO - set_weight_link_or_dist: link
# 2021-12-03 21:23:48,745 - INFO - init_weight_inf_or_zero: zero
# 2021-12-03 21:23:48,749 - INFO - Loaded file PEMSD4.rel, shape=(307, 307)
# 2021-12-03 21:23:48,750 - INFO - Loading file PEMSD4.dyna
# 2021-12-03 21:23:52,566 - INFO - Loaded file PEMSD4.dyna, shape=(16992, 307, 3)
# 2021-12-03 21:23:57,150 - INFO - closeness: (12949, 24, 307, 3)
# 2021-12-03 21:23:57,659 - INFO - period: (12949, 12, 307, 3)
# 2021-12-03 21:23:58,649 - INFO - trend: (12949, 24, 307, 3)
# 2021-12-03 21:24:04,998 - INFO - Dataset created
# 2021-12-03 21:24:04,999 - INFO - x shape: (12949, 60, 307, 3), y shape: (12949, 12, 307, 3)
# 2021-12-03 21:24:05,016 - INFO - train	x: (7769, 60, 307, 3), y: (7769, 12, 307, 3)
# 2021-12-03 21:24:05,017 - INFO - eval	x: (2590, 60, 307, 3), y: (2590, 12, 307, 3)
# 2021-12-03 21:24:05,018 - INFO - test	x: (2590, 60, 307, 3), y: (2590, 12, 307, 3)
# 2021-12-03 21:30:03,616 - INFO - Saved at ./libcity/cache/dataset_cache/point_based_PEMSD4_2_1_2_1_7_12_0.6_0.2_standard_64_False_False_True.npz
# 2021-12-03 21:30:06,831 - INFO - StandardScaler mean: 91.72662831592437, std: 127.5481471486698
# 2021-12-03 21:30:06,834 - INFO - NoneScaler
# 122 7808 (60, 307, 3) (12, 307, 3) 64
# 41 2624 (60, 307, 3) (12, 307, 3) 64
# 41 2624 (60, 307, 3) (12, 307, 3) 64
# (307, 307)
# 340.0
# 2021-12-03 21:30:17,232 - INFO - ASTGCN(
#   (hours_ASTGCN_submodule): ASTGCNSubmodule(
#     (BlockList): ModuleList(
#       (0): ASTGCNBlock(
#         (TAt): TemporalAttentionLayer()
#         (SAt): SpatialAttentionLayer()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 2), padding=(0, 1))
#         (residual_conv): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 2))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ASTGCNBlock(
#         (TAt): TemporalAttentionLayer()
#         (SAt): SpatialAttentionLayer()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (residual_conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (final_conv): Conv2d(12, 12, kernel_size=(1, 62), stride=(1, 1))
#     (fusionlayer): FusionLayer()
#   )
#   (days_ASTGCN_submodule): ASTGCNSubmodule(
#     (BlockList): ModuleList(
#       (0): ASTGCNBlock(
#         (TAt): TemporalAttentionLayer()
#         (SAt): SpatialAttentionLayer()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (residual_conv): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ASTGCNBlock(
#         (TAt): TemporalAttentionLayer()
#         (SAt): SpatialAttentionLayer()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (residual_conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (final_conv): Conv2d(12, 12, kernel_size=(1, 62), stride=(1, 1))
#     (fusionlayer): FusionLayer()
#   )
#   (weeks_ASTGCN_submodule): ASTGCNSubmodule(
#     (BlockList): ModuleList(
#       (0): ASTGCNBlock(
#         (TAt): TemporalAttentionLayer()
#         (SAt): SpatialAttentionLayer()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 2), padding=(0, 1))
#         (residual_conv): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 2))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ASTGCNBlock(
#         (TAt): TemporalAttentionLayer()
#         (SAt): SpatialAttentionLayer()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (residual_conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (final_conv): Conv2d(12, 12, kernel_size=(1, 62), stride=(1, 1))
#     (fusionlayer): FusionLayer()
#   )
# )
# 2021-12-03 21:30:17,234 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-03 21:30:17,235 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.U2	torch.Size([3, 307])	cuda:0	True
# 2021-12-03 21:30:17,236 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.U3	torch.Size([3])	cuda:0	True
# 2021-12-03 21:30:17,237 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.be	torch.Size([1, 24, 24])	cuda:0	True
# 2021-12-03 21:30:17,239 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.Ve	torch.Size([24, 24])	cuda:0	True
# 2021-12-03 21:30:17,240 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.W1	torch.Size([24])	cuda:0	True
# 2021-12-03 21:30:17,240 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.W2	torch.Size([3, 24])	cuda:0	True
# 2021-12-03 21:30:17,241 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.W3	torch.Size([3])	cuda:0	True
# 2021-12-03 21:30:17,243 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-03 21:30:17,243 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-03 21:30:17,244 - INFO - hours_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.0	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,245 - INFO - hours_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.1	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,245 - INFO - hours_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.2	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,246 - INFO - hours_ASTGCN_submodule.BlockList.0.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-03 21:30:17,246 - INFO - hours_ASTGCN_submodule.BlockList.0.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,248 - INFO - hours_ASTGCN_submodule.BlockList.0.residual_conv.weight	torch.Size([64, 3, 1, 1])	cuda:0	True
# 2021-12-03 21:30:17,249 - INFO - hours_ASTGCN_submodule.BlockList.0.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,250 - INFO - hours_ASTGCN_submodule.BlockList.0.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,251 - INFO - hours_ASTGCN_submodule.BlockList.0.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,251 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-03 21:30:17,252 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.U2	torch.Size([64, 307])	cuda:0	True
# 2021-12-03 21:30:17,252 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.U3	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,253 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.be	torch.Size([1, 12, 12])	cuda:0	True
# 2021-12-03 21:30:17,253 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.Ve	torch.Size([12, 12])	cuda:0	True
# 2021-12-03 21:30:17,254 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.W1	torch.Size([12])	cuda:0	True
# 2021-12-03 21:30:17,255 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.W2	torch.Size([64, 12])	cuda:0	True
# 2021-12-03 21:30:17,255 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.W3	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,256 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-03 21:30:17,256 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-03 21:30:17,257 - INFO - hours_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.0	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,257 - INFO - hours_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.1	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,258 - INFO - hours_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.2	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,258 - INFO - hours_ASTGCN_submodule.BlockList.1.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-03 21:30:17,259 - INFO - hours_ASTGCN_submodule.BlockList.1.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,259 - INFO - hours_ASTGCN_submodule.BlockList.1.residual_conv.weight	torch.Size([64, 64, 1, 1])	cuda:0	True
# 2021-12-03 21:30:17,260 - INFO - hours_ASTGCN_submodule.BlockList.1.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,260 - INFO - hours_ASTGCN_submodule.BlockList.1.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,261 - INFO - hours_ASTGCN_submodule.BlockList.1.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,261 - INFO - hours_ASTGCN_submodule.final_conv.weight	torch.Size([12, 12, 1, 62])	cuda:0	True
# 2021-12-03 21:30:17,262 - INFO - hours_ASTGCN_submodule.final_conv.bias	torch.Size([12])	cuda:0	True
# 2021-12-03 21:30:17,263 - INFO - hours_ASTGCN_submodule.fusionlayer.weights	torch.Size([1, 12, 307, 3])	cuda:0	True
# 2021-12-03 21:30:17,263 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-03 21:30:17,264 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.U2	torch.Size([3, 307])	cuda:0	True
# 2021-12-03 21:30:17,264 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.U3	torch.Size([3])	cuda:0	True
# 2021-12-03 21:30:17,265 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.be	torch.Size([1, 12, 12])	cuda:0	True
# 2021-12-03 21:30:17,265 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.Ve	torch.Size([12, 12])	cuda:0	True
# 2021-12-03 21:30:17,266 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.W1	torch.Size([12])	cuda:0	True
# 2021-12-03 21:30:17,271 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.W2	torch.Size([3, 12])	cuda:0	True
# 2021-12-03 21:30:17,271 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.W3	torch.Size([3])	cuda:0	True
# 2021-12-03 21:30:17,272 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-03 21:30:17,273 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-03 21:30:17,274 - INFO - days_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.0	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,274 - INFO - days_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.1	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,275 - INFO - days_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.2	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,275 - INFO - days_ASTGCN_submodule.BlockList.0.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-03 21:30:17,276 - INFO - days_ASTGCN_submodule.BlockList.0.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,277 - INFO - days_ASTGCN_submodule.BlockList.0.residual_conv.weight	torch.Size([64, 3, 1, 1])	cuda:0	True
# 2021-12-03 21:30:17,278 - INFO - days_ASTGCN_submodule.BlockList.0.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,278 - INFO - days_ASTGCN_submodule.BlockList.0.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,279 - INFO - days_ASTGCN_submodule.BlockList.0.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,280 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-03 21:30:17,280 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.U2	torch.Size([64, 307])	cuda:0	True
# 2021-12-03 21:30:17,281 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.U3	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,282 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.be	torch.Size([1, 12, 12])	cuda:0	True
# 2021-12-03 21:30:17,282 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.Ve	torch.Size([12, 12])	cuda:0	True
# 2021-12-03 21:30:17,283 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.W1	torch.Size([12])	cuda:0	True
# 2021-12-03 21:30:17,284 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.W2	torch.Size([64, 12])	cuda:0	True
# 2021-12-03 21:30:17,284 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.W3	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,285 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-03 21:30:17,285 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-03 21:30:17,286 - INFO - days_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.0	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,287 - INFO - days_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.1	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,287 - INFO - days_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.2	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,288 - INFO - days_ASTGCN_submodule.BlockList.1.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-03 21:30:17,289 - INFO - days_ASTGCN_submodule.BlockList.1.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,290 - INFO - days_ASTGCN_submodule.BlockList.1.residual_conv.weight	torch.Size([64, 64, 1, 1])	cuda:0	True
# 2021-12-03 21:30:17,290 - INFO - days_ASTGCN_submodule.BlockList.1.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,291 - INFO - days_ASTGCN_submodule.BlockList.1.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,292 - INFO - days_ASTGCN_submodule.BlockList.1.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,292 - INFO - days_ASTGCN_submodule.final_conv.weight	torch.Size([12, 12, 1, 62])	cuda:0	True
# 2021-12-03 21:30:17,293 - INFO - days_ASTGCN_submodule.final_conv.bias	torch.Size([12])	cuda:0	True
# 2021-12-03 21:30:17,293 - INFO - days_ASTGCN_submodule.fusionlayer.weights	torch.Size([1, 12, 307, 3])	cuda:0	True
# 2021-12-03 21:30:17,294 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-03 21:30:17,295 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.U2	torch.Size([3, 307])	cuda:0	True
# 2021-12-03 21:30:17,296 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.U3	torch.Size([3])	cuda:0	True
# 2021-12-03 21:30:17,296 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.be	torch.Size([1, 24, 24])	cuda:0	True
# 2021-12-03 21:30:17,297 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.Ve	torch.Size([24, 24])	cuda:0	True
# 2021-12-03 21:30:17,298 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.W1	torch.Size([24])	cuda:0	True
# 2021-12-03 21:30:17,298 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.W2	torch.Size([3, 24])	cuda:0	True
# 2021-12-03 21:30:17,299 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.W3	torch.Size([3])	cuda:0	True
# 2021-12-03 21:30:17,299 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-03 21:30:17,300 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-03 21:30:17,301 - INFO - weeks_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.0	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,302 - INFO - weeks_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.1	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,303 - INFO - weeks_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.2	torch.Size([3, 64])	cuda:0	True
# 2021-12-03 21:30:17,303 - INFO - weeks_ASTGCN_submodule.BlockList.0.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-03 21:30:17,304 - INFO - weeks_ASTGCN_submodule.BlockList.0.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,304 - INFO - weeks_ASTGCN_submodule.BlockList.0.residual_conv.weight	torch.Size([64, 3, 1, 1])	cuda:0	True
# 2021-12-03 21:30:17,305 - INFO - weeks_ASTGCN_submodule.BlockList.0.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,306 - INFO - weeks_ASTGCN_submodule.BlockList.0.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,306 - INFO - weeks_ASTGCN_submodule.BlockList.0.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,307 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-03 21:30:17,307 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.U2	torch.Size([64, 307])	cuda:0	True
# 2021-12-03 21:30:17,309 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.U3	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,309 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.be	torch.Size([1, 12, 12])	cuda:0	True
# 2021-12-03 21:30:17,310 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.Ve	torch.Size([12, 12])	cuda:0	True
# 2021-12-03 21:30:17,310 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.W1	torch.Size([12])	cuda:0	True
# 2021-12-03 21:30:17,311 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.W2	torch.Size([64, 12])	cuda:0	True
# 2021-12-03 21:30:17,311 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.W3	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,312 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-03 21:30:17,313 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-03 21:30:17,314 - INFO - weeks_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.0	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,314 - INFO - weeks_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.1	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,315 - INFO - weeks_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.2	torch.Size([64, 64])	cuda:0	True
# 2021-12-03 21:30:17,316 - INFO - weeks_ASTGCN_submodule.BlockList.1.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-03 21:30:17,316 - INFO - weeks_ASTGCN_submodule.BlockList.1.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,317 - INFO - weeks_ASTGCN_submodule.BlockList.1.residual_conv.weight	torch.Size([64, 64, 1, 1])	cuda:0	True
# 2021-12-03 21:30:17,317 - INFO - weeks_ASTGCN_submodule.BlockList.1.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,318 - INFO - weeks_ASTGCN_submodule.BlockList.1.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,319 - INFO - weeks_ASTGCN_submodule.BlockList.1.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-03 21:30:17,319 - INFO - weeks_ASTGCN_submodule.final_conv.weight	torch.Size([12, 12, 1, 62])	cuda:0	True
# 2021-12-03 21:30:17,320 - INFO - weeks_ASTGCN_submodule.final_conv.bias	torch.Size([12])	cuda:0	True
# 2021-12-03 21:30:17,321 - INFO - weeks_ASTGCN_submodule.fusionlayer.weights	torch.Size([1, 12, 307, 3])	cuda:0	True
# 2021-12-03 21:30:17,322 - INFO - Total parameter numbers: 1387671
# 2021-12-03 21:30:17,323 - INFO - You select `adam` optimizer.
# 2021-12-03 21:30:17,325 - WARNING - Received none train loss func and will use the loss func defined in the model.
# 2021-12-03 21:30:17,326 - INFO - Start training ...
# 2021-12-03 21:30:17,327 - INFO - num_batches:122
# 2021-12-03 21:31:30,558 - INFO - epoch complete!
# 2021-12-03 21:31:30,561 - INFO - evaluating now!
# 2021-12-03 21:31:42,109 - INFO - Epoch [0/100] train_loss: 14569.6473, val_loss: 10443.3095, lr: 0.000100, 84.78s
# 2021-12-03 21:31:42,177 - INFO - Saved model at 0
# 2021-12-03 21:31:42,178 - INFO - Val loss decrease from inf to 10443.3095, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch0.tar
# 2021-12-03 21:32:55,227 - INFO - epoch complete!
# 2021-12-03 21:32:55,230 - INFO - evaluating now!
# 2021-12-03 21:33:07,673 - INFO - Epoch [1/100] train_loss: 7065.2714, val_loss: 4440.2466, lr: 0.000100, 85.49s
# 2021-12-03 21:33:07,728 - INFO - Saved model at 1
# 2021-12-03 21:33:07,729 - INFO - Val loss decrease from 10443.3095 to 4440.2466, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch1.tar
# 2021-12-03 21:34:20,278 - INFO - epoch complete!
# 2021-12-03 21:34:20,282 - INFO - evaluating now!
# 2021-12-03 21:34:32,440 - INFO - Epoch [2/100] train_loss: 2927.3951, val_loss: 1722.9457, lr: 0.000100, 84.71s
# 2021-12-03 21:34:32,494 - INFO - Saved model at 2
# 2021-12-03 21:34:32,495 - INFO - Val loss decrease from 4440.2466 to 1722.9457, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch2.tar
# 2021-12-03 21:35:46,487 - INFO - epoch complete!
# 2021-12-03 21:35:46,489 - INFO - evaluating now!
# 2021-12-03 21:35:58,265 - INFO - Epoch [3/100] train_loss: 1405.8393, val_loss: 1045.4335, lr: 0.000100, 85.77s
# 2021-12-03 21:35:58,313 - INFO - Saved model at 3
# 2021-12-03 21:35:58,314 - INFO - Val loss decrease from 1722.9457 to 1045.4335, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch3.tar
# 2021-12-03 21:37:11,372 - INFO - epoch complete!
# 2021-12-03 21:37:11,375 - INFO - evaluating now!
# 2021-12-03 21:37:23,374 - INFO - Epoch [4/100] train_loss: 1013.8302, val_loss: 823.7366, lr: 0.000100, 85.06s
# 2021-12-03 21:37:23,422 - INFO - Saved model at 4
# 2021-12-03 21:37:23,423 - INFO - Val loss decrease from 1045.4335 to 823.7366, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch4.tar
# 2021-12-03 21:38:36,268 - INFO - epoch complete!
# 2021-12-03 21:38:36,271 - INFO - evaluating now!
# 2021-12-03 21:38:47,544 - INFO - Epoch [5/100] train_loss: 849.9949, val_loss: 716.0508, lr: 0.000100, 84.12s
# 2021-12-03 21:38:47,591 - INFO - Saved model at 5
# 2021-12-03 21:38:47,592 - INFO - Val loss decrease from 823.7366 to 716.0508, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch5.tar
# 2021-12-03 21:40:01,804 - INFO - epoch complete!
# 2021-12-03 21:40:01,808 - INFO - evaluating now!
# 2021-12-03 21:40:13,566 - INFO - Epoch [6/100] train_loss: 754.0424, val_loss: 654.4240, lr: 0.000100, 85.97s
# 2021-12-03 21:40:13,615 - INFO - Saved model at 6
# 2021-12-03 21:40:13,616 - INFO - Val loss decrease from 716.0508 to 654.4240, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch6.tar
# 2021-12-03 21:41:26,133 - INFO - epoch complete!
# 2021-12-03 21:41:26,136 - INFO - evaluating now!
# 2021-12-03 21:41:38,297 - INFO - Epoch [7/100] train_loss: 690.3825, val_loss: 612.5336, lr: 0.000100, 84.68s
# 2021-12-03 21:41:38,347 - INFO - Saved model at 7
# 2021-12-03 21:41:38,348 - INFO - Val loss decrease from 654.4240 to 612.5336, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch7.tar
# 2021-12-03 21:42:50,223 - INFO - epoch complete!
# 2021-12-03 21:42:50,226 - INFO - evaluating now!
# 2021-12-03 21:43:02,416 - INFO - Epoch [8/100] train_loss: 643.5758, val_loss: 581.2053, lr: 0.000100, 84.07s
# 2021-12-03 21:43:02,470 - INFO - Saved model at 8
# 2021-12-03 21:43:02,471 - INFO - Val loss decrease from 612.5336 to 581.2053, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch8.tar
# 2021-12-03 21:44:17,011 - INFO - epoch complete!
# 2021-12-03 21:44:17,016 - INFO - evaluating now!
# 2021-12-03 21:44:28,941 - INFO - Epoch [9/100] train_loss: 607.9290, val_loss: 560.1523, lr: 0.000100, 86.47s
# 2021-12-03 21:44:28,998 - INFO - Saved model at 9
# 2021-12-03 21:44:28,999 - INFO - Val loss decrease from 581.2053 to 560.1523, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch9.tar
# 2021-12-03 21:45:37,685 - INFO - epoch complete!
# 2021-12-03 21:45:37,692 - INFO - evaluating now!
# 2021-12-03 21:45:48,783 - INFO - Epoch [10/100] train_loss: 579.8149, val_loss: 543.9979, lr: 0.000100, 79.78s
# 2021-12-03 21:45:48,831 - INFO - Saved model at 10
# 2021-12-03 21:45:48,832 - INFO - Val loss decrease from 560.1523 to 543.9979, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch10.tar
# 2021-12-03 21:46:55,724 - INFO - epoch complete!
# 2021-12-03 21:46:55,727 - INFO - evaluating now!
# 2021-12-03 21:47:07,557 - INFO - Epoch [11/100] train_loss: 555.8788, val_loss: 528.2083, lr: 0.000100, 78.72s
# 2021-12-03 21:47:07,606 - INFO - Saved model at 11
# 2021-12-03 21:47:07,607 - INFO - Val loss decrease from 543.9979 to 528.2083, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch11.tar
# 2021-12-03 21:48:15,602 - INFO - epoch complete!
# 2021-12-03 21:48:15,606 - INFO - evaluating now!
# 2021-12-03 21:48:26,923 - INFO - Epoch [12/100] train_loss: 536.2228, val_loss: 519.0206, lr: 0.000100, 79.32s
# 2021-12-03 21:48:26,972 - INFO - Saved model at 12
# 2021-12-03 21:48:26,973 - INFO - Val loss decrease from 528.2083 to 519.0206, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch12.tar
# 2021-12-03 21:49:41,628 - INFO - epoch complete!
# 2021-12-03 21:49:41,632 - INFO - evaluating now!
# 2021-12-03 21:49:53,586 - INFO - Epoch [13/100] train_loss: 520.4568, val_loss: 510.3232, lr: 0.000100, 86.61s
# 2021-12-03 21:49:53,797 - INFO - Saved model at 13
# 2021-12-03 21:49:53,799 - INFO - Val loss decrease from 519.0206 to 510.3232, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch13.tar
# 2021-12-03 21:51:06,567 - INFO - epoch complete!
# 2021-12-03 21:51:06,570 - INFO - evaluating now!
# 2021-12-03 21:51:18,616 - INFO - Epoch [14/100] train_loss: 506.3678, val_loss: 503.1121, lr: 0.000100, 84.82s
# 2021-12-03 21:51:18,670 - INFO - Saved model at 14
# 2021-12-03 21:51:18,671 - INFO - Val loss decrease from 510.3232 to 503.1121, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch14.tar
# 2021-12-03 21:52:31,254 - INFO - epoch complete!
# 2021-12-03 21:52:31,257 - INFO - evaluating now!
# 2021-12-03 21:52:43,204 - INFO - Epoch [15/100] train_loss: 494.0160, val_loss: 497.4992, lr: 0.000100, 84.53s
# 2021-12-03 21:52:43,262 - INFO - Saved model at 15
# 2021-12-03 21:52:43,264 - INFO - Val loss decrease from 503.1121 to 497.4992, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epo
saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch31.tar
# 2021-12-03 22:16:26,811 - INFO - epoch complete!
# 2021-12-03 22:16:26,814 - INFO - evaluating now!
# 2021-12-03 22:16:39,014 - INFO - Epoch [32/100] train_loss: 394.4215, val_loss: 438.7227, lr: 0.000100, 86.98s
# 2021-12-03 22:16:39,069 - INFO - Saved model at 32
# 2021-12-03 22:16:39,070 - INFO - Val loss decrease from 442.2785 to 438.7227, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch32.tar
# 2021-12-03 22:17:52,738 - INFO - epoch complete!
# 2021-12-03 22:17:52,742 - INFO - evaluating now!
# 2021-12-03 22:18:05,043 - INFO - Epoch [33/100] train_loss: 391.1686, val_loss: 438.0845, lr: 0.000100, 85.97s
# 2021-12-03 22:18:05,096 - INFO - Saved model at 33
# 2021-12-03 22:18:05,097 - INFO - Val loss decrease from 438.7227 to 438.0845, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch33.tar
# 2021-12-03 22:19:18,945 - INFO - epoch complete!
# 2021-12-03 22:19:18,949 - INFO - evaluating now!
# 2021-12-03 22:19:31,340 - INFO - Epoch [34/100] train_loss: 387.9641, val_loss: 434.9087, lr: 0.000100, 86.24s
# 2021-12-03 22:19:31,397 - INFO - Saved model at 34
# 2021-12-03 22:19:31,398 - INFO - Val loss decrease from 438.0845 to 434.9087, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch34.tar
# 2021-12-03 22:20:44,583 - INFO - epoch complete!
# 2021-12-03 22:20:44,588 - INFO - evaluating now!
# 2021-12-03 22:20:56,277 - INFO - Epoch [35/100] train_loss: 385.0987, val_loss: 433.3398, lr: 0.000100, 84.88s
# 2021-12-03 22:20:56,328 - INFO - Saved model at 35
# 2021-12-03 22:20:56,329 - INFO - Val loss decrease from 434.9087 to 433.3398, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch35.tar
# 2021-12-03 22:22:08,126 - INFO - epoch complete!
# 2021-12-03 22:22:08,129 - INFO - evaluating now!
# 2021-12-03 22:22:20,393 - INFO - Epoch [36/100] train_loss: 382.4049, val_loss: 428.8488, lr: 0.000100, 84.06s
# 2021-12-03 22:22:20,447 - INFO - Saved model at 36
# 2021-12-03 22:22:20,448 - INFO - Val loss decrease from 433.3398 to 428.8488, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch36.tar
# 2021-12-03 22:23:34,042 - INFO - epoch complete!
# 2021-12-03 22:23:34,045 - INFO - evaluating now!
# 2021-12-03 22:23:45,583 - INFO - Epoch [37/100] train_loss: 379.5872, val_loss: 428.2335, lr: 0.000100, 85.13s
# 2021-12-03 22:23:45,633 - INFO - Saved model at 37
# 2021-12-03 22:23:45,635 - INFO - Val loss decrease from 428.8488 to 428.2335, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch37.tar
# 2021-12-03 22:24:58,095 - INFO - epoch complete!
# 2021-12-03 22:24:58,098 - INFO - evaluating now!
# 2021-12-03 22:25:09,850 - INFO - Epoch [38/100] train_loss: 376.6909, val_loss: 425.8230, lr: 0.000100, 84.21s
# 2021-12-03 22:25:09,899 - INFO - Saved model at 38
# 2021-12-03 22:25:09,900 - INFO - Val loss decrease from 428.2335 to 425.8230, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch38.tar
# 2021-12-03 22:26:21,238 - INFO - epoch complete!
# 2021-12-03 22:26:21,241 - INFO - evaluating now!
# 2021-12-03 22:26:32,507 - INFO - Epoch [39/100] train_loss: 374.3665, val_loss: 424.5506, lr: 0.000100, 82.61s
# 2021-12-03 22:26:32,556 - INFO - Saved model at 39
# 2021-12-03 22:26:32,558 - INFO - Val loss decrease from 425.8230 to 424.5506, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch39.tar
# 2021-12-03 22:27:44,457 - INFO - epoch complete!
# 2021-12-03 22:27:44,460 - INFO - evaluating now!
# 2021-12-03 22:27:56,092 - INFO - Epoch [40/100] train_loss: 372.1051, val_loss: 422.3349, lr: 0.000100, 83.53s
# 2021-12-03 22:27:56,146 - INFO - Saved model at 40
# 2021-12-03 22:27:56,147 - INFO - Val loss decrease from 424.5506 to 422.3349, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch40.tar
# 2021-12-03 22:29:09,702 - INFO - epoch complete!
# 2021-12-03 22:29:09,705 - INFO - evaluating now!
# 2021-12-03 22:29:21,203 - INFO - Epoch [41/100] train_loss: 370.1678, val_loss: 419.6467, lr: 0.000100, 85.05s
# 2021-12-03 22:29:21,253 - INFO - Saved model at 41
# 2021-12-03 22:29:21,254 - INFO - Val loss decrease from 422.3349 to 419.6467, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch41.tar
# 2021-12-03 22:30:34,604 - INFO - epoch complete!
# 2021-12-03 22:30:34,607 - INFO - evaluating now!
# 2021-12-03 22:30:45,137 - INFO - Epoch [42/100] train_loss: 368.0000, val_loss: 417.8857, lr: 0.000100, 83.88s
# 2021-12-03 22:30:45,185 - INFO - Saved model at 42
# 2021-12-03 22:30:45,186 - INFO - Val loss decrease from 419.6467 to 417.8857, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch42.tar
# 2021-12-03 22:31:52,489 - INFO - epoch complete!
# 2021-12-03 22:31:52,496 - INFO - evaluating now!
# 2021-12-03 22:32:04,184 - INFO - Epoch [43/100] train_loss: 366.3729, val_loss: 417.0542, lr: 0.000100, 79.00s
# 2021-12-03 22:32:04,231 - INFO - Saved model at 43
# 2021-12-03 22:32:04,232 - INFO - Val loss decrease from 417.8857 to 417.0542, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch43.tar
# 2021-12-03 22:33:11,520 - INFO - epoch complete!
# 2021-12-03 22:33:11,524 - INFO - evaluating now!
# 2021-12-03 22:33:23,370 - INFO - Epoch [44/100] train_loss: 364.3914, val_loss: 416.9324, lr: 0.000100, 79.14s
# 2021-12-03 22:33:23,421 - INFO - Saved model at 44
# 2021-12-03 22:33:23,422 - INFO - Val loss decrease from 417.0542 to 416.9324, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch44.tar
# 2021-12-03 22:34:32,239 - INFO - epoch complete!
# 2021-12-03 22:34:32,243 - INFO - evaluating now!
# 2021-12-03 22:34:42,894 - INFO - Epoch [45/100] train_loss: 362.9811, val_loss: 413.8624, lr: 0.000100, 79.47s
# 2021-12-03 22:34:42,944 - INFO - Saved model at 45
# 2021-12-03 22:34:42,946 - INFO - Val loss decrease from 416.9324 to 413.8624, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch45.tar
# 2021-12-03 22:35:49,312 - INFO - epoch complete!
# 2021-12-03 22:35:49,316 - INFO - evaluating now!
# 2021-12-03 22:36:01,328 - INFO - Epoch [46/100] train_loss: 360.9062, val_loss: 413.1658, lr: 0.000100, 78.38s
# 2021-12-03 22:36:01,378 - INFO - Saved model at 46
# 2021-12-03 22:36:01,379 - INFO - Val loss decrease from 413.8624 to 413.1658, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epo
# 8   8.104656   inf  404.831238  20.120419    8.053809     6.100633
# 9   8.175008   inf  413.438904  20.333197    8.119801     6.743100
# 10  8.350195   inf  423.480988  20.578653    8.292344     6.374527
# 11  8.448802   inf  436.970520  20.903839    8.389029     6.828865
# 12  8.809885   inf  464.583466  21.554199    8.746538     8.061825
#
#     masked_MSE  masked_RMSE        R2      EVAR
# 1   300.052643    17.322027  0.981823  0.981845
# 2   322.472931    17.957531  0.980384  0.980431
# 3   335.443512    18.315117  0.979529  0.979553
# 4   349.779236    18.702385  0.978605  0.978639
# 5   358.362457    18.930464  0.978038  0.978064
# 6   370.097748    19.237925  0.977266  0.977284
# 7   378.168945    19.446566  0.976732  0.976746
# 8   385.923187    19.644928  0.976222  0.976231
# 9   393.290192    19.831545  0.975718  0.975739
# 10  402.514191    20.062756  0.975125  0.975167
# 11  415.094055    20.373857  0.974332  0.974358
# 12  440.983093    20.999598  0.972712  0.972747

# %%
from libcity.data import get_dataset
from libcity.utils import get_executor
from libcity.utils import get_model
from libcity.utils import get_logger

config = {'task': 'traffic_state_pred', 'model': 'ASTGCN', 'dataset': 'PEMSD4', 'saved_model': True, 'train': True, 'dataset_class': 'ASTGCNDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'nb_block': 2, 'K': 3, 'nb_chev_filter': 64, 'nb_time_filter': 64, 'scaler': 'standard', 'load_external': False, 'normal_external': False, 'ext_scaler': 'none', 'add_time_in_day': False, 'add_day_in_week': False, 'train_rate': 0.6, 'eval_rate': 0.2, 'max_epoch': 100, 'learner': 'adam', 'learning_rate': 0.0001, 'lr_decay': False, 'clip_grad_norm': False, 'use_early_stop': False, 'batch_size': 64, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'input_window': 12, 'output_window': 12, 'len_closeness': 2, 'len_period': 1, 'len_trend': 2, 'interval_period': 1, 'interval_trend': 7, 'gpu': True, 'gpu_id': 0, 'train_loss': 'none', 'epoch': 0, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.1, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'max_grad_norm': 1.0, 'patience': 50, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'mode': 'single', 'save_modes': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'cost': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'traffic_flow': 'num', 'traffic_occupancy': 'num', 'traffic_speed': 'num'}}, 'data_col': ['traffic_flow', 'traffic_occupancy', 'traffic_speed'], 'weight_col': 'cost', 'data_files': ['PEMSD4'], 'geo_file': 'PEMSD4', 'rel_file': 'PEMSD4', 'output_dim': 3, 'time_intervals': 300, 'init_weight_inf_or_zero': 'zero', 'set_weight_link_or_dist': 'link', 'calculate_weight_adj': False, 'weight_adj_epsilon': 0.1}
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import torch
config['device'] = torch.device("cuda" if torch.cuda.is_available() and config['gpu'] else "cpu")

logger = get_logger(config)
# 加载数据集
dataset = get_dataset(config)
# 转换数据，并划分数据集
train_data, valid_data, test_data = dataset.get_data()
print(len(train_data), len(train_data.dataset), train_data.dataset[0][0].shape, train_data.dataset[0][1].shape, train_data.batch_size)
print(len(valid_data), len(valid_data.dataset), valid_data.dataset[0][0].shape, valid_data.dataset[0][1].shape, valid_data.batch_size)
print(len(test_data), len(test_data.dataset), test_data.dataset[0][0].shape, test_data.dataset[0][1].shape, test_data.batch_size)

data_feature = dataset.get_data_feature()
print(data_feature['adj_mx'].shape)
print(data_feature['adj_mx'].sum())

model =ASTGCN(config, data_feature)

# 加载执行器
model_cache_file = './libcity/cache/model_cache/' + config['model'] + '_' + config['dataset'] + '.m'
executor = get_executor(config, model)

# 训练
executor.train(train_data, valid_data)
executor.save_model(model_cache_file)
executor.load_model(model_cache_file)
# 评估，评估结果将会放在 cache/evaluate_cache 下
executor.evaluate(test_data)
# Out:
# 2021-12-06 20:29:11,290 - INFO - Log directory: ./libcity/log
# 2021-12-06 20:29:11,969 - INFO - Loaded file PEMSD4.geo, num_nodes=307
# 2021-12-06 20:29:11,972 - INFO - set_weight_link_or_dist: link
# 2021-12-06 20:29:11,973 - INFO - init_weight_inf_or_zero: zero
# 2021-12-06 20:29:11,977 - INFO - Loaded file PEMSD4.rel, shape=(307, 307)
# 2021-12-06 20:29:11,978 - INFO - Loading ./libcity/cache/dataset_cache/point_based_PEMSD4_2_1_2_1_7_12_0.6_0.2_standard_64_False_False_True.npz
# 2021-12-06 20:29:45,945 - INFO - train	x: (7769, 60, 307, 3), y: (7769, 12, 307, 3)
# 2021-12-06 20:29:45,947 - INFO - eval	x: (2590, 60, 307, 3), y: (2590, 12, 307, 3)
# 2021-12-06 20:29:45,948 - INFO - test	x: (2590, 60, 307, 3), y: (2590, 12, 307, 3)
# 2021-12-06 20:29:48,469 - INFO - StandardScaler mean: 91.72662831592477, std: 127.5481471486703
# 2021-12-06 20:29:48,471 - INFO - NoneScaler
# 122 7808 (60, 307, 3) (12, 307, 3) 64
# 41 2624 (60, 307, 3) (12, 307, 3) 64
# 41 2624 (60, 307, 3) (12, 307, 3) 64
# (307, 307)
# 340.0
# 2021-12-06 20:29:58,602 - INFO - ASTGCN(
#   (hours_ASTGCN_submodule): ASTGCNSubmodule(
#     (BlockList): ModuleList(
#       (0): ASTGCNBlock(
#         (TAt): TemporalAttention()
#         (SAt): SpatialAttention()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 2), padding=(0, 1))
#         (residual_conv): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 2))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ASTGCNBlock(
#         (TAt): TemporalAttention()
#         (SAt): SpatialAttention()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (residual_conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (final_conv): Conv2d(12, 12, kernel_size=(1, 62), stride=(1, 1))
#     (fusionlayer): FusionLayer()
#   )
#   (days_ASTGCN_submodule): ASTGCNSubmodule(
#     (BlockList): ModuleList(
#       (0): ASTGCNBlock(
#         (TAt): TemporalAttention()
#         (SAt): SpatialAttention()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (residual_conv): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ASTGCNBlock(
#         (TAt): TemporalAttention()
#         (SAt): SpatialAttention()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (residual_conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (final_conv): Conv2d(12, 12, kernel_size=(1, 62), stride=(1, 1))
#     (fusionlayer): FusionLayer()
#   )
#   (weeks_ASTGCN_submodule): ASTGCNSubmodule(
#     (BlockList): ModuleList(
#       (0): ASTGCNBlock(
#         (TAt): TemporalAttention()
#         (SAt): SpatialAttention()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 3x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 2), padding=(0, 1))
#         (residual_conv): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 2))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ASTGCNBlock(
#         (TAt): TemporalAttention()
#         (SAt): SpatialAttention()
#         (cheb_conv_SAt): ChebConvWithSAt(
#           (Theta): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 64x64 (GPU 0)]
#           )
#         )
#         (time_conv): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (residual_conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (final_conv): Conv2d(12, 12, kernel_size=(1, 62), stride=(1, 1))
#     (fusionlayer): FusionLayer()
#   )
# )
# 2021-12-06 20:29:58,604 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-06 20:29:58,605 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.U2	torch.Size([3, 307])	cuda:0	True
# 2021-12-06 20:29:58,607 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.U3	torch.Size([3])	cuda:0	True
# 2021-12-06 20:29:58,607 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.be	torch.Size([1, 24, 24])	cuda:0	True
# 2021-12-06 20:29:58,608 - INFO - hours_ASTGCN_submodule.BlockList.0.TAt.Ve	torch.Size([24, 24])	cuda:0	True
# 2021-12-06 20:29:58,609 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.W1	torch.Size([24])	cuda:0	True
# 2021-12-06 20:29:58,611 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.W2	torch.Size([3, 24])	cuda:0	True
# 2021-12-06 20:29:58,611 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.W3	torch.Size([3])	cuda:0	True
# 2021-12-06 20:29:58,612 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-06 20:29:58,613 - INFO - hours_ASTGCN_submodule.BlockList.0.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-06 20:29:58,613 - INFO - hours_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.0	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,614 - INFO - hours_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.1	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,615 - INFO - hours_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.2	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,616 - INFO - hours_ASTGCN_submodule.BlockList.0.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-06 20:29:58,616 - INFO - hours_ASTGCN_submodule.BlockList.0.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,617 - INFO - hours_ASTGCN_submodule.BlockList.0.residual_conv.weight	torch.Size([64, 3, 1, 1])	cuda:0	True
# 2021-12-06 20:29:58,618 - INFO - hours_ASTGCN_submodule.BlockList.0.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,618 - INFO - hours_ASTGCN_submodule.BlockList.0.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,619 - INFO - hours_ASTGCN_submodule.BlockList.0.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,619 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-06 20:29:58,620 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.U2	torch.Size([64, 307])	cuda:0	True
# 2021-12-06 20:29:58,621 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.U3	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,621 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.be	torch.Size([1, 12, 12])	cuda:0	True
# 2021-12-06 20:29:58,622 - INFO - hours_ASTGCN_submodule.BlockList.1.TAt.Ve	torch.Size([12, 12])	cuda:0	True
# 2021-12-06 20:29:58,622 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.W1	torch.Size([12])	cuda:0	True
# 2021-12-06 20:29:58,623 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.W2	torch.Size([64, 12])	cuda:0	True
# 2021-12-06 20:29:58,624 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.W3	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,624 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-06 20:29:58,625 - INFO - hours_ASTGCN_submodule.BlockList.1.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-06 20:29:58,625 - INFO - hours_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.0	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,626 - INFO - hours_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.1	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,627 - INFO - hours_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.2	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,631 - INFO - hours_ASTGCN_submodule.BlockList.1.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-06 20:29:58,632 - INFO - hours_ASTGCN_submodule.BlockList.1.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,633 - INFO - hours_ASTGCN_submodule.BlockList.1.residual_conv.weight	torch.Size([64, 64, 1, 1])	cuda:0	True
# 2021-12-06 20:29:58,633 - INFO - hours_ASTGCN_submodule.BlockList.1.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,634 - INFO - hours_ASTGCN_submodule.BlockList.1.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,635 - INFO - hours_ASTGCN_submodule.BlockList.1.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,636 - INFO - hours_ASTGCN_submodule.final_conv.weight	torch.Size([12, 12, 1, 62])	cuda:0	True
# 2021-12-06 20:29:58,636 - INFO - hours_ASTGCN_submodule.final_conv.bias	torch.Size([12])	cuda:0	True
# 2021-12-06 20:29:58,637 - INFO - hours_ASTGCN_submodule.fusionlayer.weights	torch.Size([1, 12, 307, 3])	cuda:0	True
# 2021-12-06 20:29:58,637 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-06 20:29:58,638 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.U2	torch.Size([3, 307])	cuda:0	True
# 2021-12-06 20:29:58,639 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.U3	torch.Size([3])	cuda:0	True
# 2021-12-06 20:29:58,640 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.be	torch.Size([1, 12, 12])	cuda:0	True
# 2021-12-06 20:29:58,640 - INFO - days_ASTGCN_submodule.BlockList.0.TAt.Ve	torch.Size([12, 12])	cuda:0	True
# 2021-12-06 20:29:58,641 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.W1	torch.Size([12])	cuda:0	True
# 2021-12-06 20:29:58,641 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.W2	torch.Size([3, 12])	cuda:0	True
# 2021-12-06 20:29:58,642 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.W3	torch.Size([3])	cuda:0	True
# 2021-12-06 20:29:58,643 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-06 20:29:58,644 - INFO - days_ASTGCN_submodule.BlockList.0.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-06 20:29:58,644 - INFO - days_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.0	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,645 - INFO - days_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.1	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,645 - INFO - days_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.2	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,646 - INFO - days_ASTGCN_submodule.BlockList.0.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-06 20:29:58,647 - INFO - days_ASTGCN_submodule.BlockList.0.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,648 - INFO - days_ASTGCN_submodule.BlockList.0.residual_conv.weight	torch.Size([64, 3, 1, 1])	cuda:0	True
# 2021-12-06 20:29:58,648 - INFO - days_ASTGCN_submodule.BlockList.0.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,649 - INFO - days_ASTGCN_submodule.BlockList.0.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,650 - INFO - days_ASTGCN_submodule.BlockList.0.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,650 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-06 20:29:58,651 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.U2	torch.Size([64, 307])	cuda:0	True
# 2021-12-06 20:29:58,652 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.U3	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,652 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.be	torch.Size([1, 12, 12])	cuda:0	True
# 2021-12-06 20:29:58,653 - INFO - days_ASTGCN_submodule.BlockList.1.TAt.Ve	torch.Size([12, 12])	cuda:0	True
# 2021-12-06 20:29:58,654 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.W1	torch.Size([12])	cuda:0	True
# 2021-12-06 20:29:58,654 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.W2	torch.Size([64, 12])	cuda:0	True
# 2021-12-06 20:29:58,655 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.W3	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,656 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-06 20:29:58,657 - INFO - days_ASTGCN_submodule.BlockList.1.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-06 20:29:58,657 - INFO - days_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.0	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,658 - INFO - days_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.1	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,659 - INFO - days_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.2	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,660 - INFO - days_ASTGCN_submodule.BlockList.1.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-06 20:29:58,661 - INFO - days_ASTGCN_submodule.BlockList.1.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,661 - INFO - days_ASTGCN_submodule.BlockList.1.residual_conv.weight	torch.Size([64, 64, 1, 1])	cuda:0	True
# 2021-12-06 20:29:58,662 - INFO - days_ASTGCN_submodule.BlockList.1.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,666 - INFO - days_ASTGCN_submodule.BlockList.1.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,666 - INFO - days_ASTGCN_submodule.BlockList.1.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,667 - INFO - days_ASTGCN_submodule.final_conv.weight	torch.Size([12, 12, 1, 62])	cuda:0	True
# 2021-12-06 20:29:58,668 - INFO - days_ASTGCN_submodule.final_conv.bias	torch.Size([12])	cuda:0	True
# 2021-12-06 20:29:58,669 - INFO - days_ASTGCN_submodule.fusionlayer.weights	torch.Size([1, 12, 307, 3])	cuda:0	True
# 2021-12-06 20:29:58,669 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-06 20:29:58,670 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.U2	torch.Size([3, 307])	cuda:0	True
# 2021-12-06 20:29:58,671 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.U3	torch.Size([3])	cuda:0	True
# 2021-12-06 20:29:58,673 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.be	torch.Size([1, 24, 24])	cuda:0	True
# 2021-12-06 20:29:58,674 - INFO - weeks_ASTGCN_submodule.BlockList.0.TAt.Ve	torch.Size([24, 24])	cuda:0	True
# 2021-12-06 20:29:58,675 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.W1	torch.Size([24])	cuda:0	True
# 2021-12-06 20:29:58,675 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.W2	torch.Size([3, 24])	cuda:0	True
# 2021-12-06 20:29:58,676 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.W3	torch.Size([3])	cuda:0	True
# 2021-12-06 20:29:58,678 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-06 20:29:58,678 - INFO - weeks_ASTGCN_submodule.BlockList.0.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-06 20:29:58,679 - INFO - weeks_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.0	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,680 - INFO - weeks_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.1	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,681 - INFO - weeks_ASTGCN_submodule.BlockList.0.cheb_conv_SAt.Theta.2	torch.Size([3, 64])	cuda:0	True
# 2021-12-06 20:29:58,682 - INFO - weeks_ASTGCN_submodule.BlockList.0.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-06 20:29:58,683 - INFO - weeks_ASTGCN_submodule.BlockList.0.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,683 - INFO - weeks_ASTGCN_submodule.BlockList.0.residual_conv.weight	torch.Size([64, 3, 1, 1])	cuda:0	True
# 2021-12-06 20:29:58,684 - INFO - weeks_ASTGCN_submodule.BlockList.0.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,684 - INFO - weeks_ASTGCN_submodule.BlockList.0.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,685 - INFO - weeks_ASTGCN_submodule.BlockList.0.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,686 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.U1	torch.Size([307])	cuda:0	True
# 2021-12-06 20:29:58,688 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.U2	torch.Size([64, 307])	cuda:0	True
# 2021-12-06 20:29:58,689 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.U3	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,689 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.be	torch.Size([1, 12, 12])	cuda:0	True
# 2021-12-06 20:29:58,690 - INFO - weeks_ASTGCN_submodule.BlockList.1.TAt.Ve	torch.Size([12, 12])	cuda:0	True
# 2021-12-06 20:29:58,691 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.W1	torch.Size([12])	cuda:0	True
# 2021-12-06 20:29:58,691 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.W2	torch.Size([64, 12])	cuda:0	True
# 2021-12-06 20:29:58,693 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.W3	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,693 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.bs	torch.Size([1, 307, 307])	cuda:0	True
# 2021-12-06 20:29:58,694 - INFO - weeks_ASTGCN_submodule.BlockList.1.SAt.Vs	torch.Size([307, 307])	cuda:0	True
# 2021-12-06 20:29:58,695 - INFO - weeks_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.0	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,696 - INFO - weeks_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.1	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,696 - INFO - weeks_ASTGCN_submodule.BlockList.1.cheb_conv_SAt.Theta.2	torch.Size([64, 64])	cuda:0	True
# 2021-12-06 20:29:58,697 - INFO - weeks_ASTGCN_submodule.BlockList.1.time_conv.weight	torch.Size([64, 64, 1, 3])	cuda:0	True
# 2021-12-06 20:29:58,698 - INFO - weeks_ASTGCN_submodule.BlockList.1.time_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,699 - INFO - weeks_ASTGCN_submodule.BlockList.1.residual_conv.weight	torch.Size([64, 64, 1, 1])	cuda:0	True
# 2021-12-06 20:29:58,699 - INFO - weeks_ASTGCN_submodule.BlockList.1.residual_conv.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,700 - INFO - weeks_ASTGCN_submodule.BlockList.1.ln.weight	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,701 - INFO - weeks_ASTGCN_submodule.BlockList.1.ln.bias	torch.Size([64])	cuda:0	True
# 2021-12-06 20:29:58,702 - INFO - weeks_ASTGCN_submodule.final_conv.weight	torch.Size([12, 12, 1, 62])	cuda:0	True
# 2021-12-06 20:29:58,702 - INFO - weeks_ASTGCN_submodule.final_conv.bias	torch.Size([12])	cuda:0	True
# 2021-12-06 20:29:58,703 - INFO - weeks_ASTGCN_submodule.fusionlayer.weights	torch.Size([1, 12, 307, 3])	cuda:0	True
# 2021-12-06 20:29:58,705 - INFO - Total parameter numbers: 1387671
# 2021-12-06 20:29:58,705 - INFO - You select `adam` optimizer.
# 2021-12-06 20:29:58,707 - WARNING - Received none train loss func and will use the loss func defined in the model.
# 2021-12-06 20:29:58,708 - INFO - Start training ...
# 2021-12-06 20:29:58,709 - INFO - num_batches:122
# 2021-12-06 20:31:09,791 - INFO - epoch complete!
# 2021-12-06 20:31:09,794 - INFO - evaluating now!
# 2021-12-06 20:31:20,550 - INFO - Epoch [0/100] train_loss: 14549.4294, val_loss: 10471.9376, lr: 0.000100, 81.84s
# 2021-12-06 20:31:20,649 - INFO - Saved model at 0
# 2021-12-06 20:31:20,650 - INFO - Val loss decrease from inf to 10471.9376, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch0.tar
# 2021-12-06 20:32:32,206 - INFO - epoch complete!
# 2021-12-06 20:32:32,209 - INFO - evaluating now!
# 2021-12-06 20:32:42,783 - INFO - Epoch [1/100] train_loss: 6848.0446, val_loss: 3804.3599, lr: 0.000100, 82.13s
# 2021-12-06 20:32:42,865 - INFO - Saved model at 1
# 2021-12-06 20:32:42,866 - INFO - Val loss decrease from 10471.9376 to 3804.3599, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch1.tar
# 2021-12-06 20:33:54,079 - INFO - epoch complete!
# 2021-12-06 20:33:54,083 - INFO - evaluating now!
# 2021-12-06 20:34:05,495 - INFO - Epoch [2/100] train_loss: 2266.2867, val_loss: 1247.3380, lr: 0.000100, 82.63s
# 2021-12-06 20:34:05,581 - INFO - Saved model at 2
# 2021-12-06 20:34:05,582 - INFO - Val loss decrease from 3804.3599 to 1247.3380, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch2.tar
# 2021-12-06 20:35:18,289 - INFO - epoch complete!
# 2021-12-06 20:35:18,293 - INFO - evaluating now!
# 2021-12-06 20:35:28,741 - INFO - Epoch [3/100] train_loss: 1070.0266, val_loss: 835.8826, lr: 0.000100, 83.16s
# 2021-12-06 20:35:28,821 - INFO - Saved model at 3
# 2021-12-06 20:35:28,822 - INFO - Val loss decrease from 1247.3380 to 835.8826, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch3.tar
# 2021-12-06 20:36:39,604 - INFO - epoch complete!
# 2021-12-06 20:36:39,607 - INFO - evaluating now!
# 2021-12-06 20:36:50,351 - INFO - Epoch [4/100] train_loss: 825.2313, val_loss: 704.1525, lr: 0.000100, 81.53s
# 2021-12-06 20:36:50,438 - INFO - Saved model at 4
# 2021-12-06 20:36:50,440 - INFO - Val loss decrease from 835.8826 to 704.1525, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch4.tar
# 2021-12-06 20:38:02,601 - INFO - epoch complete!
# 2021-12-06 20:38:02,604 - INFO - evaluating now!
# 2021-12-06 20:38:13,569 - INFO - Epoch [5/100] train_loss: 714.4381, val_loss: 637.5835, lr: 0.000100, 83.13s
# 2021-12-06 20:38:13,654 - INFO - Saved model at 5
# 2021-12-06 20:38:13,655 - INFO - Val loss decrease from 704.1525 to 637.5835, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch5.tar
# 2021-12-06 20:39:24,908 - INFO - epoch complete!
# 2021-12-06 20:39:24,912 - INFO - evaluating now!
# 2021-12-06 20:39:35,583 - INFO - Epoch [6/100] train_loss: 645.1370, val_loss: 600.6021, lr: 0.000100, 81.93s
# 2021-12-06 20:39:35,667 - INFO - Saved model at 6
# 2021-12-06 20:39:35,668 - INFO - Val loss decrease from 637.5835 to 600.6021, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch6.tar
# 2021-12-06 20:40:42,220 - INFO - epoch complete!
# 2021-12-06 20:40:42,224 - INFO - evaluating now!
# 2021-12-06 20:40:53,354 - INFO - Epoch [7/100] train_loss: 594.7056, val_loss: 573.9505, lr: 0.000100, 77.69s
# 2021-12-06 20:40:53,540 - INFO - Saved model at 7
# 2021-12-06 20:40:53,542 - INFO - Val loss decrease from 600.6021 to 573.9505, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch7.tar
# 2021-12-06 20:42:06,553 - INFO - epoch complete!
# 2021-12-06 20:42:06,557 - INFO - evaluating now!
# 2021-12-06 20:42:16,828 - INFO - Epoch [8/100] train_loss: 557.0531, val_loss: 552.8508, lr: 0.000100, 83.29s
# 2021-12-06 20:42:16,916 - INFO - Saved model at 8
# 2021-12-06 20:42:16,917 - INFO - Val loss decrease from 573.9505 to 552.8508, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch8.tar
# 2021-12-06 20:43:27,004 - INFO - epoch complete!
# 2021-12-06 20:43:27,009 - INFO - evaluating now!
# 2021-12-06 20:43:36,769 - INFO - Epoch [9/100] train_loss: 528.2173, val_loss: 539.6903, lr: 0.000100, 79.85s
# 2021-12-06 20:43:36,852 - INFO - Saved model at 9
# 2021-12-06 20:43:36,853 - INFO - Val loss decrease from 552.8508 to 539.6903, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch9.tar
# 2021-12-06 20:44:41,440 - INFO - epoch complete!
# 2021-12-06 20:44:41,443 - INFO - evaluating now!
# 2021-12-06 20:44:52,749 - INFO - Epoch [10/100] train_loss: 505.2743, val_loss: 527.8413, lr: 0.000100, 75.89s
# 2021-12-06 20:44:52,831 - INFO - Saved model at 10
# 2021-12-06 20:44:52,832 - INFO - Val loss decrease from 539.6903 to 527.8413, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch10.tar
# 2021-12-06 20:45:59,015 - INFO - epoch complete!
# 2021-12-06 20:45:59,018 - INFO - evaluating now!
# 2021-12-06 20:46:09,215 - INFO - Epoch [11/100] train_loss: 485.5561, val_loss: 520.2737, lr: 0.000100, 76.38s
# 2021-12-06 20:46:09,295 - INFO - Saved model at 11
# 2021-12-06 20:46:09,296 - INFO - Val loss decrease from 527.8413 to 520.2737, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch11.tar
# 2021-12-06 20:47:19,838 - INFO - epoch complete!
# 2021-12-06 20:47:19,842 - INFO - evaluating now!
# 2021-12-06 20:47:31,912 - INFO - Epoch [12/100] train_loss: 470.6095, val_loss: 514.1774, lr: 0.000100, 82.62s
# 2021-12-06 20:47:31,995 - INFO - Saved model at 12
# 2021-12-06 20:47:31,996 - INFO - Val loss decrease from 520.2737 to 514.1774, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch12.tar
# 2021-12-06 20:48:42,581 - INFO - epoch complete!
# 2021-12-06 20:48:42,586 - INFO - evaluating now!
# 2021-12-06 20:48:53,726 - INFO - Epoch [13/100] train_loss: 458.0413, val_loss: 506.5170, lr: 0.000100, 81.73s
# 2021-12-06 20:48:53,814 - INFO - Saved model at 13
# 2021-12-06 20:48:53,815 - INFO - Val loss decrease from 514.1774 to 506.5170, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch13.tar
# 2021-12-06 20:50:04,417 - INFO - epoch complete!
# 2021-12-06 20:50:04,421 - INFO - evaluating now!
# 2021-12-06 20:50:14,871 - INFO - Epoch [14/100] train_loss: 446.5151, val_loss: 504.9375, lr: 0.000100, 81.05s
# 2021-12-06 20:50:14,952 - INFO - Saved model at 14
# 2021-12-06 20:50:14,953 - INFO - Val loss decrease from 506.5170 to 504.9375, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch14.tar
# 2021-12-06 20:51:25,066 - INFO - epoch complete!
# 2021-12-06 20:51:25,071 - INFO - evaluating now!
# 2021-12-06 20:51:35,908 - INFO - Epoch [15/100] train_loss: 437.3545, val_loss: 498.4477, lr: 0.000100, 80.95s
# 2021-12-06 20:51:35,994 - INFO - Saved model at 15
# 2021-12-06 20:51:35,995 - INFO - Val loss decrease from 504.9375 to 498.4477, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch15.tar
# 2021-12-06 20:52:43,189 - INFO - epoch complete!
# 2021-12-06 20:52:43,193 - INFO - evaluating now!
# 2021-12-06 20:52:53,890 - INFO - Epoch [16/100] train_loss: 428.7483, val_loss: 492.2432, lr: 0.000100, 77.89s
# 2021-12-06 20:52:53,941 - INFO - Saved model at 16
# 2021-12-06 20:52:53,942 - INFO - Val loss decrease from 498.4477 to 492.2432, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch16.tar
# 2021-12-06 20:54:07,643 - INFO - epoch complete!
# 2021-12-06 20:54:07,648 - INFO - evaluating now!
# 2021-12-06 20:54:18,767 - INFO - Epoch [17/100] train_loss: 421.0466, val_loss: 488.1041, lr: 0.000100, 84.82s
# 2021-12-06 20:54:18,856 - INFO - Saved model at 17
# 2021-12-06 20:54:18,857 - INFO - Val loss decrease from 492.2432 to 488.1041, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch17.tar
# 2021-12-06 20:55:28,568 - INFO - epoch complete!
# 2021-12-06 20:55:28,571 - INFO - evaluating now!
# 2021-12-06 20:55:39,331 - INFO - Epoch [18/100] train_loss: 414.4101, val_loss: 484.5659, lr: 0.000100, 80.47s
# 2021-12-06 20:55:39,413 - INFO - Saved model at 18
# 2021-12-06 20:55:39,414 - INFO - Val loss decrease from 488.1041 to 484.5659, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epoch18.tar
# 2021-12-06 20:56:50,672 - INFO - epoch complete!
# 2021-12-06 20:56:50,676 - INFO - evaluating now!
# 2021-12-06 20:57:01,117 - INFO - Epoch [19/100] train_loss: 407.6767, val_loss: 479.1340, lr: 0.000100, 81.70s
# 2021-12-06 20:57:01,199 - INFO - Saved model at 19
# 2021-12-06 20:57:01,201 - INFO - Val loss decrease from 484.5659 to 479.1340, saving to ./libcity/cache/model_cache/ASTGCN_PEMSD4_epo
# 2021-12-06 22:32:49,365 - INFO - evaluating now!
# 2021-12-06 22:32:59,758 - INFO - Epoch [90/100] train_loss: 295.1987, val_loss: 430.1808, lr: 0.000100, 80.41s
# 2021-12-06 22:34:09,745 - INFO - epoch complete!
# 2021-12-06 22:34:09,749 - INFO - evaluating now!
# 2021-12-06 22:34:20,431 - INFO - Epoch [91/100] train_loss: 294.7613, val_loss: 433.3186, lr: 0.000100, 80.67s
# 2021-12-06 22:35:26,760 - INFO - epoch complete!
# 2021-12-06 22:35:26,763 - INFO - evaluating now!
# 2021-12-06 22:35:37,650 - INFO - Epoch [92/100] train_loss: 294.1264, val_loss: 432.4576, lr: 0.000100, 77.21s
# 2021-12-06 22:36:42,954 - INFO - epoch complete!
# 2021-12-06 22:36:42,957 - INFO - evaluating now!
# 2021-12-06 22:36:53,100 - INFO - Epoch [93/100] train_loss: 293.5318, val_loss: 432.4867, lr: 0.000100, 75.45s
# 2021-12-06 22:38:06,531 - INFO - epoch complete!
# 2021-12-06 22:38:06,535 - INFO - evaluating now!
# 2021-12-06 22:38:18,058 - INFO - Epoch [94/100] train_loss: 293.1564, val_loss: 432.9178, lr: 0.000100, 84.96s
# 2021-12-06 22:39:27,825 - INFO - epoch complete!
# 2021-12-06 22:39:27,832 - INFO - evaluating now!
# 2021-12-06 22:39:38,536 - INFO - Epoch [95/100] train_loss: 292.9288, val_loss: 434.3008, lr: 0.000100, 80.48s
# 2021-12-06 22:40:51,477 - INFO - epoch complete!
# 2021-12-06 22:40:51,481 - INFO - evaluating now!
# 2021-12-06 22:41:02,290 - INFO - Epoch [96/100] train_loss: 292.1578, val_loss: 433.0870, lr: 0.000100, 83.75s
# 2021-12-06 22:42:13,061 - INFO - epoch complete!
# 2021-12-06 22:42:13,064 - INFO - evaluating now!
# 2021-12-06 22:42:23,529 - INFO - Epoch [97/100] train_loss: 291.8937, val_loss: 434.7946, lr: 0.000100, 81.24s
# 2021-12-06 22:43:34,720 - INFO - epoch complete!
# 2021-12-06 22:43:34,724 - INFO - evaluating now!
# 2021-12-06 22:43:46,336 - INFO - Epoch [98/100] train_loss: 291.5913, val_loss: 434.4405, lr: 0.000100, 82.80s
# 2021-12-06 22:44:59,133 - INFO - epoch complete!
# 2021-12-06 22:44:59,137 - INFO - evaluating now!
# 2021-12-06 22:45:09,609 - INFO - Epoch [99/100] train_loss: 291.0548, val_loss: 435.3313, lr: 0.000100, 83.27s
# 2021-12-06 22:45:09,611 - INFO - Trained totally 100 epochs, average train time is 70.349s, average eval time is 10.714s
# 2021-12-06 22:45:09,659 - INFO - Loaded model at 55
# 2021-12-06 22:45:09,661 - INFO - Saved model at ./libcity/cache/model_cache/ASTGCN_PEMSD4.m
# 2021-12-06 22:45:09,739 - INFO - Loaded model at ./libcity/cache/model_cache/ASTGCN_PEMSD4.m
# 2021-12-06 22:45:09,797 - INFO - Start evaluating ...
# 2021-12-06 22:45:44,213 - INFO - Note that you select the single mode to evaluate!
